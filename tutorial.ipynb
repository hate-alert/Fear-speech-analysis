# %%
from textnets import Corpus, Textnet

# %%
from textnets import examples

# %%
corpus = Corpus(examples.moon_landing)

# %%
corpus.tokenized()
# Out:
#                         term  n
# label
# Boston Globe             man  1
# Boston Globe            moon  1
# Boston Globe            walk  1
# Chicago Tribune          1st  1
# Chicago Tribune    armstrong  1
# Chicago Tribune        giant  1
# Chicago Tribune         leap  1
# Chicago Tribune      mankind  1
# Chicago Tribune         moon  1
# Chicago Tribune         step  1
# Chicago Tribune         take  1
# Houston Chronicle    aldrich  1
# Houston Chronicle  armstrong  1
# Houston Chronicle        man  1
# Houston Chronicle       moon  1
# Houston Chronicle      small  1
# Houston Chronicle       step  1
# Los Angeles Times      giant  1
# Los Angeles Times       leap  1
# Los Angeles Times        man  1
# Los Angeles Times    mankind  1
# Los Angeles Times       moon  1
# Los Angeles Times      small  1
# Los Angeles Times       step  1
# Los Angeles Times       walk  1
# New York Times     astronaut  1
# New York Times       collect  1
# New York Times          flag  1
# New York Times          land  1
# New York Times           man  1
# New York Times          moon  1
# New York Times         plain  1
# New York Times         plant  1
# New York Times         rocks  1
# New York Times          walk  1
# The Guardian            3:56  1
# The Guardian             man  1
# The Guardian            moon  1
# The Guardian            step  1
# Washington Post        eagle  1
# Washington Post         land  1
# Washington Post          men  1
# Washington Post         moon  1
# Washington Post         walk  1

# %%
examples.moon_landing.head(1)
# Out:
# The Guardian    3:56 am: Man Steps On to the Moon
# Name: headlines, dtype: object

# %%
tn = Textnet(corpus.tokenized(), min_docs=1)

# %%
tn.plot(label_term_nodes=True,
        label_doc_nodes=True,
        show_clusters=True)

# %%
papers = tn.project(node_type='doc')
papers.plot(label_nodes=True)

# %%
words = tn.project(node_type='term')
words.plot(label_nodes=True,
           show_clusters=True)

# %%
papers.top_betweenness()
# Out:
# Los Angeles Times    7.0
# Washington Post      0.0
# The Guardian         0.0
# New York Times       0.0
# Houston Chronicle    0.0
# Chicago Tribune      0.0
# Boston Globe         0.0
# dtype: float64

# %%
words.top_betweenness()
# Out:
# walk         63.000000
# man          28.000000
# land         16.000000
# mankind       8.666667
# giant         8.666667
# leap          8.666667
# step          8.000000
# small         6.500000
# armstrong     4.500000
# plain         0.000000
# dtype: float64

# %%
words.plot(label_nodes=True,
           scale_nodes_by='betweenness',
           color_clusters=True,
           alpha=0.5,
           node_label_filter=lambda n: n.betweenness() > words.betweenness.median())
